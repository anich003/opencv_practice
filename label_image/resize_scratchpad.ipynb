# %%
import cv2
import skimage.io as io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = io.imread('../data/shannyn.jpg')
plt.imshow(img)

# %%
img.shape
# Out:
# (600, 800, 3)

# %%
h,w,_ = img.shape

# %%
max_width = 200
scale     = 200/w

# %%
new_height= h * scale

# %%
new_height
# Out:
# 150.0

# %%
from skimage.transform import downscale_local_mean, resize

# %%
#down = downscale_local_mean(img,(2,2,1))
down = resize(img, (new_height,max_width))

# %%
plt.imshow(down)
